# %%
from matplotlib.dates import DateFormatter
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
import matplotlib.ticker as ticker
fig, ax = plt.subplots()
sns.pointplot(data = Agent_time_line, x= 'ActivityTime', y= 'hour'\
              , hue = 'BasicActivity', ax = ax, linestyles='', alpha = 0.8)
# ax.legend(loc='right')
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
trange = np.arange(0,10, 0.1)
x_dates = Agent_time_line['ActivityTime'].dt.strftime('%m-%d')
ax.set_xticks(range(len(x_dates)))
ax.set_xticklabels(labels=x_dates, rotation=90, ha='right')
# ax.set_ylim([0,24])
# date_form = DateFormatter("%m-%d")
# ax.xaxis.set_major_formatter(date_form)
ax.xaxis.set_major_locator(ticker.MultipleLocator(8))
ax.grid()

# %%
fig , ax = plt.subplots()
for specific_activity in activity_list:
    Agent_specific_activity = Agent_time_line.loc[Agent_time_line['BasicActivity']== specific_activity]
    ax.scatter(Agent_specific_activity['ActivityTime'], Agent_specific_activity['hour']\
             , label = specific_activity, alpha = 0.8, edgecolor = 'k', s=45)

ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
fig.savefig("specificAgentt.png", dpi = 300, bbox_inches='tight')

# %%
fig, ax = plt.subplots()
specific_activity = 'Nutrition programme'
activity_list = ['Daily session', 'Nutrition programme', 'Trails App Run', 'Personal exercise', 'Weekly Bonus']
for specific_activity in activity_list:
    ax.hist( Activity.loc[Activity['BasicActivity'] == specific_activity, 'hour']\
            , alpha = 0.6 , label = specific_activity, density = True, bins = 24)
ax.legend()
fig.savefig('Activity-timing.png')

# %%
g = sns.PairGrid( Activity.groupby('REF_PARTNER').mean() )
g.map_diag(plt.hist, bins=20)

def pairgrid_heatmap(x, y, **kws):
    cmap = sns.light_palette(kws.pop("color"), as_cmap=True)
    plt.hist2d(x, y, cmap=cmap, cmin=1, **kws)

g.map_offdiag(pairgrid_heatmap, bins=10)
plt.savefig('Age-Hour.png')
